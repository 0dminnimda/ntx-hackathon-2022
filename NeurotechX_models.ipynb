# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import shap

# %%
from sklearn.linear_model import LogisticRegression

# %%
data_all = pd.read_csv('Matrix_final_classif.csv')
data_all
# Out:
#      film  Subj  Alpha_Fz  Alpha_F3  Alpha_F7  Alpha_C3  Alpha_T7  Alpha_Pz  \
# 0     1.0   1.0  2.526810  1.913928  4.005514  2.027418  4.022892  1.949431
# 1     2.0   1.0  2.422609  1.693390  4.184985  1.749329  4.286330  1.903182
# 2     3.0   1.0  2.961759  2.105665  4.111915  2.149489  3.840039  2.494217
# 3     4.0   1.0  2.841711  2.009766  4.550318  1.964755  4.471460  2.415181
# 4     5.0   1.0  2.735525  1.719663  4.984611  1.625007  4.578527  1.806550
# ..    ...   ...       ...       ...       ...       ...       ...       ...
# 161   5.0  21.0       NaN       NaN       NaN       NaN       NaN       NaN
# 162   3.0  21.0       NaN       NaN       NaN       NaN       NaN       NaN
# 163   7.0  21.0       NaN       NaN       NaN       NaN       NaN       NaN
# 164   6.0  21.0       NaN       NaN       NaN       NaN       NaN       NaN
# 165   2.0  21.0       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Alpha_P3  Alpha_P7  ...        sd1        sd2            s   sd1/sd2  \
# 0    1.321008  1.879488  ...  36.004782  63.728486  7208.479428  0.564972
# 1    1.228613  1.775213  ...  32.386361  93.884034  9552.207890  0.344961
# 2    1.444414  1.953797  ...  33.106061  57.626465  5993.484072  0.574494
# 3    1.546809  1.995032  ...  34.323741  55.708897  6007.158031  0.616127
# 4    1.229363  2.054360  ...  32.350690  66.163187  6724.342727  0.488953
# ..        ...       ...  ...        ...        ...          ...       ...
# 161       NaN       NaN  ...  16.551727  36.532664  1899.654127  0.453067
# 162       NaN       NaN  ...  16.091991  59.828525  3024.600108  0.268969
# 163       NaN       NaN  ...  18.028114  62.002796  3511.651726  0.290763
# 164       NaN       NaN  ...  14.824270  58.258877  2713.221811  0.254455
# 165       NaN       NaN  ...  18.202655  48.813435  2791.412256  0.372903
#
#      breathingrate           EDA    Corr_watch  Corr_Watch-relax  Zygom_watch  \
# 0         0.126139  1.071543e-05  4.584045e-06     -2.363670e-06     0.000008
# 1         0.127548  1.436167e-06  5.025006e-06     -3.596841e-08     0.000008
# 2         0.110211  7.873740e-07  5.367433e-06     -1.253883e-06     0.000006
# 3         0.112641  2.621115e-06  5.493949e-06     -5.846554e-07     0.000007
# 4         0.100000  1.977819e-06  6.065049e-06     -5.153287e-07     0.000006
# ..             ...           ...           ...               ...          ...
# 161       0.333333  1.586434e-08  4.105661e-07      1.819826e-09     0.000002
# 162       0.300399  1.521037e-07  4.091630e-07      1.107719e-10     0.000002
# 163       0.115463  2.699324e-08  4.106556e-07      4.663283e-10     0.000002
# 164       0.128018  4.118254e-08  4.107057e-07      6.195613e-10     0.000002
# 165       0.152431  4.694813e-08  4.120631e-07     -5.575971e-11     0.000002
#
#      Zygom_Watch-relax
# 0         1.361368e-06
# 1         1.414074e-06
# 2        -3.219226e-06
# 3        -3.041387e-06
# 4        -1.598777e-07
# ..                 ...
# 161      -1.218309e-06
# 162      -3.530825e-07
# 163      -3.687755e-07
# 164      -3.542369e-07
# 165      -6.626327e-07
#
# [166 rows x 520 columns]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp = IterativeImputer(max_iter=10, random_state=0)
data_all = pd.DataFrame(imp.fit_transform(data_all),columns=imp.feature_names_in_)
data_all
# Out:
#      film  Subj  Alpha_Fz  Alpha_F3  Alpha_F7  Alpha_C3  Alpha_T7  Alpha_Pz  \
# 0     1.0   1.0  2.526810  1.913928  4.005514  2.027418  4.022892  1.949431
# 1     2.0   1.0  2.422609  1.693390  4.184985  1.749329  4.286330  1.903182
# 2     3.0   1.0  2.961759  2.105665  4.111915  2.149489  3.840039  2.494217
# 3     4.0   1.0  2.841711  2.009766  4.550318  1.964755  4.471460  2.415181
# 4     5.0   1.0  2.735525  1.719663  4.984611  1.625007  4.578527  1.806550
# ..    ...   ...       ...       ...       ...       ...       ...       ...
# 161   5.0  21.0  3.111720  3.374355  5.007262  5.014128  5.591337  5.754549
# 162   3.0  21.0  3.240271  3.635476  4.996440  4.588444  5.520314  6.326243
# 163   7.0  21.0  3.093850  4.080741  5.912176  4.404728  6.177493  7.574871
# 164   6.0  21.0  3.059588  3.487503  5.169773  4.656410  5.821828  6.631693
# 165   2.0  21.0  3.058240  3.351593  4.643681  4.809598  5.256642  5.922145
#
#      Alpha_P3  Alpha_P7  ...        sd1        sd2            s   sd1/sd2  \
# 0    1.321008  1.879488  ...  36.004782  63.728486  7208.479428  0.564972
# 1    1.228613  1.775213  ...  32.386361  93.884034  9552.207890  0.344961
# 2    1.444414  1.953797  ...  33.106061  57.626465  5993.484072  0.574494
# 3    1.546809  1.995032  ...  34.323741  55.708897  6007.158031  0.616127
# 4    1.229363  2.054360  ...  32.350690  66.163187  6724.342727  0.488953
# ..        ...       ...  ...        ...        ...          ...       ...
# 161  3.445571  4.860382  ...  16.551727  36.532664  1899.654127  0.453067
# 162  3.429652  4.865195  ...  16.091991  59.828525  3024.600108  0.268969
# 163  3.105449  5.374474  ...  18.028114  62.002796  3511.651726  0.290763
# 164  3.546197  5.031374  ...  14.824270  58.258877  2713.221811  0.254455
# 165  3.719157  4.888648  ...  18.202655  48.813435  2791.412256  0.372903
#
#      breathingrate           EDA    Corr_watch  Corr_Watch-relax  Zygom_watch  \
# 0         0.126139  1.071543e-05  4.584045e-06     -2.363670e-06     0.000008
# 1         0.127548  1.436167e-06  5.025006e-06     -3.596841e-08     0.000008
# 2         0.110211  7.873740e-07  5.367433e-06     -1.253883e-06     0.000006
# 3         0.112641  2.621115e-06  5.493949e-06     -5.846554e-07     0.000007
# 4         0.100000  1.977819e-06  6.065049e-06     -5.153287e-07     0.000006
# ..             ...           ...           ...               ...          ...
# 161       0.333333  1.586434e-08  4.105661e-07      1.819826e-09     0.000002
# 162       0.300399  1.521037e-07  4.091630e-07      1.107719e-10     0.000002
# 163       0.115463  2.699324e-08  4.106556e-07      4.663283e-10     0.000002
# 164       0.128018  4.118254e-08  4.107057e-07      6.195613e-10     0.000002
# 165       0.152431  4.694813e-08  4.120631e-07     -5.575971e-11     0.000002
#
#      Zygom_Watch-relax
# 0         1.361368e-06
# 1         1.414074e-06
# 2        -3.219226e-06
# 3        -3.041387e-06
# 4        -1.598777e-07
# ..                 ...
# 161      -1.218309e-06
# 162      -3.530825e-07
# 163      -3.687755e-07
# 164      -3.542369e-07
# 165      -6.626327e-07
#
# [166 rows x 520 columns]

# %%
result = pd.DataFrame()
grid_res = []
n_films = 8
n_subjects = 21
sr = []
for film in range(1, n_films + 1):
    X_test = data_all.loc[(data_all['film'] == film)].reset_index(drop=True)
    X_train = data_all.loc[(data_all['film'] != film)].reset_index(drop=True)

    y_train = X_train['Labels']
    y_test = np.array(X_test['Labels'])
    train_film = X_train['film']
    train_subj = X_train['Subj']
    #train_ch = X_train['ch']
    test_film = X_test['film']
    test_subj = X_test['Subj']
    #test_ch = np.array(X_test['ch'])
    X_train = X_train.drop(['Subj', 'film', 'Labels'], axis=1)
    X_test = X_test.drop(['Subj', 'film', 'Labels'], axis=1)
    forest = ExtraTreesClassifier(n_estimators=250, max_depth=5, random_state=1)
    forest.fit(X_train, y_train)

    importances = forest.feature_importances_
    std = np.std(
        [tree.feature_importances_ for tree in forest.estimators_],
        axis=0
    )
    indices = np.argsort(importances)[::-1]
    indices = indices[:TOP_FEATURES]

    print('Top features:')
    for f in range(TOP_FEATURES):
        print('%d. feature %d (%f)' % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Top features:
# 1. feature 497 (0.011004)
# 2. feature 103 (0.008857)
# 3. feature 256 (0.008490)
# 4. feature 487 (0.007799)
# 5. feature 495 (0.007151)
# 6. feature 348 (0.006351)
# 7. feature 448 (0.005546)
# 8. feature 143 (0.005239)
# 9. feature 90 (0.005225)
# 10. feature 488 (0.005150)
# 11. feature 439 (0.005037)
# 12. feature 452 (0.005022)
# 13. feature 104 (0.004938)
# 14. feature 419 (0.004928)
# 15. feature 179 (0.004848)
# Top features:
# 1. feature 497 (0.011006)
# 2. feature 207 (0.009782)
# 3. feature 143 (0.008658)
# 4. feature 256 (0.008440)
# 5. feature 382 (0.007984)
# 6. feature 87 (0.005763)
# 7. feature 386 (0.005718)
# 8. feature 487 (0.005576)
# 9. feature 130 (0.005520)
# 10. feature 212 (0.005343)
# 11. feature 68 (0.005259)
# 12. feature 378 (0.005131)
# 13. feature 384 (0.005064)
# 14. feature 489 (0.004879)
# 15. feature 205 (0.004799)
# Top features:
# 1. feature 256 (0.012001)
# 2. feature 384 (0.007720)
# 3. feature 295 (0.007134)
# 4. feature 386 (0.006928)
# 5. feature 497 (0.006477)
# 6. feature 391 (0.005861)
# 7. feature 143 (0.005795)
# 8. feature 25 (0.005514)
# 9. feature 134 (0.005069)
# 10. feature 452 (0.005031)
# 11. feature 444 (0.004975)
# 12. feature 313 (0.004922)
# 13. feature 381 (0.004920)
# 14. feature 348 (0.004874)
# 15. feature 288 (0.004712)
# Top features:
# 1. feature 379 (0.009279)
# 2. feature 497 (0.009004)
# 3. feature 486 (0.008973)
# 4. feature 115 (0.008562)
# 5. feature 207 (0.007484)
# 6. feature 393 (0.007416)
# 7. feature 487 (0.007319)
# 8. feature 209 (0.007023)
# 9. feature 130 (0.006945)
# 10. feature 253 (0.006477)
# 11. feature 206 (0.006377)
# 12. feature 387 (0.006365)
# 13. feature 395 (0.006342)
# 14. feature 386 (0.006236)
# 15. feature 394 (0.006137)
# Top features:
# 1. feature 497 (0.014320)
# 2. feature 391 (0.011775)
# 3. feature 382 (0.009697)
# 4. feature 387 (0.009518)
# 5. feature 392 (0.007441)
# 6. feature 489 (0.007329)
# 7. feature 395 (0.007099)
# 8. feature 380 (0.007050)
# 9. feature 390 (0.006991)
# 10. feature 383 (0.006891)
# 11. feature 487 (0.006864)
# 12. feature 491 (0.006745)
# 13. feature 207 (0.006743)
# 14. feature 393 (0.006616)
# 15. feature 389 (0.006522)
# Top features:
# 1. feature 256 (0.009179)
# 2. feature 391 (0.008710)
# 3. feature 394 (0.008050)
# 4. feature 486 (0.007635)
# 5. feature 436 (0.006587)
# 6. feature 130 (0.006434)
# 7. feature 382 (0.006265)
# 8. feature 487 (0.006139)
# 9. feature 327 (0.006100)
# 10. feature 393 (0.006099)
# 11. feature 253 (0.005901)
# 12. feature 497 (0.005643)
# 13. feature 68 (0.005265)
# 14. feature 208 (0.005230)
# 15. feature 87 (0.005227)
# Top features:
# 1. feature 497 (0.011677)
# 2. feature 256 (0.009433)
# 3. feature 394 (0.008203)
# 4. feature 393 (0.007690)
# 5. feature 384 (0.006964)
# 6. feature 143 (0.006167)
# 7. feature 348 (0.006150)
# 8. feature 382 (0.006134)
# 9. feature 387 (0.005970)
# 10. feature 311 (0.005920)
# 11. feature 395 (0.005809)
# 12. feature 381 (0.005747)
# 13. feature 390 (0.005580)
# 14. feature 80 (0.005260)
# 15. feature 386 (0.005255)
# Top features:
# 1. feature 256 (0.008171)
# 2. feature 497 (0.008128)
# 3. feature 115 (0.007558)
# 4. feature 87 (0.007467)
# 5. feature 486 (0.006177)
# 6. feature 487 (0.006057)
# 7. feature 391 (0.006051)
# 8. feature 452 (0.005959)
# 9. feature 103 (0.005644)
# 10. feature 130 (0.005631)
# 11. feature 253 (0.005562)
# 12. feature 77 (0.005515)
# 13. feature 429 (0.005514)
# 14. feature 451 (0.005369)
# 15. feature 99 (0.005361)

# %%
from sklearn.ensemble import ExtraTreesClassifier

TOP_FEATURES = 15

forest = ExtraTreesClassifier(n_estimators=250, max_depth=5, random_state=1)
forest.fit(train[labels], train['target'])

importances = forest.feature_importances_
std = np.std(
    [tree.feature_importances_ for tree in forest.estimators_],
    axis=0
)
indices = np.argsort(importances)[::-1]
indices = indices[:TOP_FEATURES]

print('Top features:')
for f in range(TOP_FEATURES):
    print('%d. feature %d (%f)' % (f + 1, indices[f], importances[indices[f]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 6>()
#       3 TOP_FEATURES = 15
#       5 forest = ExtraTreesClassifier(n_estimators=250, max_depth=5, random_state=1)
# ----> 6 forest.fit(train[labels], train['target'])
#       8 importances = forest.feature_importances_
#       9 std = np.std(
#      10     [tree.feature_importances_ for tree in forest.estimators_],
#      11     axis=0
#      12 )
#
# NameError: name 'train' is not defined
